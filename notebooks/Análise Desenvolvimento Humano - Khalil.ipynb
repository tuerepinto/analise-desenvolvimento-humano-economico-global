# %% [markdown]
# <font color="#0D9DF0"><h3><B>Avaliação - Python Para Ciência de Dados</b></h3></font>
# ***

# %%
import sys
sys.path.append('../')
import pandas as pd
import matplotlib.pyplot as plt
from src.datasets_reader import read_gapminder_data
from src.matplot_samples import plot_line_chart
from src.matplot_samples import plot_average_per_capita_income_by_continent
from src.matplot_samples import plot_total_population_by_continent

# %%
#df_clinicos = pd.read_csv('../datasets/gapminder_full.csv', sep=',')
df = read_gapminder_data()
df
# Out:
# Arquivo ../datasets/gapminder_full.csv lido com sucesso.
#           country  year         pop continent  lifeExp   gdpPercap
# 0     Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1     Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2     Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3     Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4     Afghanistan  1972  13079460.0      Asia   36.088  739.981106
# ...           ...   ...         ...       ...      ...         ...
# 1731     Zimbabwe  1987   9216418.0    Africa   62.351  706.157306
# 1732     Zimbabwe  1992  10704340.0    Africa   60.377  693.420786
# 1733     Zimbabwe  1997  11404948.0    Africa   46.809  792.449960
# 1734     Zimbabwe  2002  11926563.0    Africa   39.989  672.038623
# 1735     Zimbabwe  2007  12311143.0    Africa   43.487  469.709298
#
# [1736 rows x 6 columns]

# %% [markdown]
# Removendo duplicatas (se houverem)

# %%
df = df.drop_duplicates() #remove registros duplicados
df = df.dropna() #remove registros com valores nulos
df
# Out:
#           country  year         pop continent  lifeExp   gdpPercap
# 0     Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1     Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2     Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3     Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4     Afghanistan  1972  13079460.0      Asia   36.088  739.981106
# ...           ...   ...         ...       ...      ...         ...
# 1731     Zimbabwe  1987   9216418.0    Africa   62.351  706.157306
# 1732     Zimbabwe  1992  10704340.0    Africa   60.377  693.420786
# 1733     Zimbabwe  1997  11404948.0    Africa   46.809  792.449960
# 1734     Zimbabwe  2002  11926563.0    Africa   39.989  672.038623
# 1735     Zimbabwe  2007  12311143.0    Africa   43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.head()
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 0  Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1  Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2  Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3  Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4  Afghanistan  1972  13079460.0      Asia   36.088  739.981106

# %% [markdown]
# Describe do dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1704 entries, 0 to 1735
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   year       1704 non-null   int64
#  2   pop        1704 non-null   float64
#  3   continent  1704 non-null   object
#  4   lifeExp    1704 non-null   float64
#  5   gdpPercap  1704 non-null   float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 93.2+ KB

# %%
print('Anos disponíveis:', df['year'].min(), '-', df['year'].max())
print('Número de países:', df['country'].nunique())
# Out:
# Anos disponíveis: 1952 - 2007
# Número de países: 142

# %% [markdown]
# #Plota grafico de Média da Expectativa de Vida por Continente

# %%
plot_line_chart(df, operationType="mean", groupByList = ['year', 'continent'], returnField = 'lifeExp', title = "Média da Expectativa de Vida por Continente", xLabel = "Ano", yLabel = "Expectativa de Vida (anos)")

# %% [markdown]
# #Plata grafico de Média do Per Capita por Continente

# %%
df.head()
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 0  Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1  Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2  Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3  Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4  Afghanistan  1972  13079460.0      Asia   36.088  739.981106

# %%
plot_line_chart(df, operationType="mean", groupByList = ['year', 'continent'], returnField = 'gdpPercap', title = "Média do Renda Per Capita Por Continente", xLabel = "Ano", yLabel = "Renda Per Capita (anos)")

# %% [markdown]
# #Plota grafico de Média Populacional por Continente

# %%
df.head()
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 0  Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1  Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2  Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3  Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4  Afghanistan  1972  13079460.0      Asia   36.088  739.981106

# %%
plot_line_chart(df, operationType="mean", groupByList = ['year', 'continent'], returnField = 'pop', title = "Média Populacional por Continente", xLabel = "Ano", yLabel = "População (anos)")
